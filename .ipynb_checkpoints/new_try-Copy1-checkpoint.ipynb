# %% [markdown]
# # Importing the necessary library

# %%
import os
import random

#hindi font
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

import numpy as np
import pandas as pd

#image display
import cv2

#tqdm used for progress bar
from tqdm.notebook import tqdm
from sklearn.metrics import accuracy_score

# %% [markdown]
# # The names of each character, in the correct order for the Hindi Devnagri script

# %%
class_names='''character_1_ka character_2_kha character_3_ga character_4_gha character_5_kna character_6_cha character_7_chha 
character_8_ja character_9_jha character_10_yna character_11_taamatar character_12_thaa character_13_daa character_14_dhaa 
character_15_adna character_16_tabala character_17_tha character_18_da character_19_dha character_20_na character_21_pa 
character_22_pha character_23_ba character_24_bha character_25_ma character_26_yaw character_27_ra character_28_la 
character_29_waw character_30_motosaw character_31_petchiryakha character_32_patalosaw character_33_ha character_34_chhya 
character_35_tra character_36_gya digit_0 digit_1 digit_2 digit_3 digit_4 digit_5 digit_6 digit_7 digit_8 digit_9'''.split()

hindi_character = 'क ख ग घ ङ च छ ज झ ञ ट ठ ड ढ ण त थ द ध न प फ ब भ म य र ल व श ष स ह ॠ त्र ज्ञ ० १ २ ३ ४ ५ ६ ७ ८ ९'.split()

# %%
print(hindi_character)
# Out:
# ['क', 'ख', 'ग', 'घ', 'ङ', 'च', 'छ', 'ज', 'झ', 'ञ', 'ट', 'ठ', 'ड', 'ढ', 'ण', 'त', 'थ', 'द', 'ध', 'न', 'प', 'फ', 'ब', 'भ', 'म', 'य', 'र', 'ल', 'व', 'श', 'ष', 'स', 'ह', 'ॠ', 'त्र', 'ज्ञ', '०', '१', '२', '३', '४', '५', '६', '७', '८', '९']

# %%
hindi_font = FontProperties(fname='./hindi-font/Nirmala.ttf') # Hindi font to display in Matplotlib

# %% [markdown]
# # Define the paths

# %%
dataset_path =r"C:\Users\DELL\jupyterr/DevanagariHandwrittenCharacterDataset_10_per_train_100_per_test"


train_dataset_path = dataset_path+"/Train"
test_dataset_path = dataset_path+"/Test"

print(f"Train Path : {train_dataset_path}")
print(f"Test Path : {test_dataset_path}")
# Out:
# Train Path : C:\Users\DELL\jupyterr/DevanagariHandwrittenCharacterDataset_10_per_train_100_per_test/Train
# Test Path : C:\Users\DELL\jupyterr/DevanagariHandwrittenCharacterDataset_10_per_train_100_per_test/Test

# %% [markdown]
# # Visualize the data

# %%
def see_random_picture(target_dir , class_name):
    target_directory = target_dir + '/' + class_name                    # Example --> Train + '/' + character_1_ka  -->  Train/character_1_ka
    random_picture_name = random.choice(os.listdir(target_directory))   # Selecting random image from Train/character_1_ka
    image_path = target_directory + '/' + random_picture_name           # let say random image name is 10963.png , so final image path would be :                                                                      #                                                     Train/character_1_ka/10963.png
    image = plt.imread(image_path) 

    hindi_char_name = hindi_character[class_names.index(class_name)]
    hindi_font = FontProperties(fname='./hindi-font/Nirmala.ttf')

    plt.figure(figsize=(2,2))
    print(f"Shape of image : {image.shape}")  #  display the shape of the image.
    plt.imshow(image , cmap='gray')
    plt.title(f"{class_name} - ({hindi_char_name})",fontproperties=hindi_font)
    plt.axis("off")

# %% [markdown]
# # Let view any random character from train data

# %%
see_random_picture(train_dataset_path,
                   random.choice(class_names))
# Out:
# Shape of image : (32, 32)

# %% [markdown]
# # Load Data

# %%
def load_data_from_directory(directory, class_names, description=None):
    all_images = []
    all_labels = []

    for class_name in tqdm(class_names,desc=description):
        target_dir = directory + "/" + class_name
        images = os.listdir(target_dir)

        for img in images:
            img_path = target_dir + "/" + img
            img_arr = cv2.imread(img_path,0).flatten()
            img_label = class_names.index(class_name)

            all_images.append(img_arr.astype('float32'))
            all_labels.append(img_label)

    return np.array(all_images), np.array(all_labels)

# %%
X_train, y_train = load_data_from_directory(train_dataset_path,class_names,"Loading train data...  ")
X_test, y_test = load_data_from_directory(test_dataset_path,class_names,"Loading test data...  ")
# Out:
# Loading train data...  :   0%|          | 0/46 [00:00<?, ?it/s]
# Loading test data...  :   0%|          | 0/46 [00:00<?, ?it/s]

# %%
X_train.shape, X_test.shape
# Out:
# ((7820, 1024), (13800, 1024))

# %%
y_train.shape, y_test.shape
# Out:
# ((7820,), (13800,))

# %%
fig, ax = plt.subplots(5,5, figsize=(15,15))
ax = ax.flatten()

for i in range(25):
    k = np.random.randint(0,len(X_train))
    
    img = X_train[k]
    label = y_train[k]
    
    ax[i].imshow(img.reshape(32,32),cmap='gray')
    ax[i].axis(False)
    ax[i].set_title(hindi_character[label],fontproperties=hindi_font, fontsize=15)

plt.show()

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# # Feature Selection: PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=0.98)  # Retain 98% of information
X_train_pca = pca.fit_transform(X_train_scaled)
X_test_pca = pca.transform(X_test_scaled)

# %%
X_train_pca.shape, X_test_pca.shape
# Out:
# ((7820, 293), (13800, 293))

# %%
pca.n_components_
# Out:
# 293

# %% [markdown]
# # Model - 1 : Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# # Train Logistic Regression model

# %%
# Train Logistic Regression model
logistic_model = LogisticRegression(max_iter=1000, n_jobs=-1)
logistic_model.fit(X_train_pca, y_train)
# Out:
# LogisticRegression(max_iter=1000, n_jobs=-1)

# %%
# Predict on the test set
y_pred = logistic_model.predict(X_test_pca)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6057971014492753

# %% [markdown]
# # Hyper parameter tunning for Logistic regression

# %%
pip install optuna
# Out:
# Requirement already satisfied: optuna in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (3.5.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: alembic>=1.5.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from optuna) (1.13.1)
# Requirement already satisfied: colorlog in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from optuna) (6.8.2)
# Requirement already satisfied: numpy in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from optuna) (1.26.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from optuna) (23.2)
# Requirement already satisfied: sqlalchemy>=1.3.0 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from optuna) (2.0.26)
# Requirement already satisfied: tqdm in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from optuna) (4.66.1)
# Requirement already satisfied: PyYAML in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from alembic>=1.5.0->optuna) (1.3.2)
# Requirement already satisfied: typing-extensions>=4 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from alembic>=1.5.0->optuna) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from sqlalchemy>=1.3.0->optuna) (3.0.3)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\dell\appdata\local\programs\python\python312\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import optuna

# %%
def objective(trial):
    # Define hyperparameters to search
    C = trial.suggest_float('C', 1e-5, 1e5, log=True)

    # Train Logistic Regression model with suggested hyperparameters
    logistic_model = LogisticRegression(C=C,max_iter=1000, n_jobs=-1)
    logistic_model.fit(X_train_pca, y_train)

    y_pred = logistic_model.predict(X_test_pca)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred)
    return 1 - accuracy 

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

# Get the best hyperparameters
best_params = study.best_params
print("Best Hyperparameters:", best_params)

# Train the model with the best hyperparameters
best_model = LogisticRegression(C=best_params['C'], max_iter=1000, n_jobs=-1)
best_model.fit(X_train_pca, y_train)

# Evaluate the best model
y_pred_final = best_model.predict(X_test_pca)
final_accuracy = accuracy_score(y_test, y_pred_final)
print(f"Final Model Accuracy: {final_accuracy:.2f}")
# Out:
# [I 2024-02-21 18:52:03,610] A new study created in memory with name: no-name-522ef11d-4fee-4f50-a530-6ed115aa04ec
# [I 2024-02-21 18:52:07,861] Trial 0 finished with value: 0.3739855072463768 and parameters: {'C': 0.0003906831348093401}. Best is trial 0 with value: 0.3739855072463768.
# [I 2024-02-21 18:52:14,019] Trial 1 finished with value: 0.4288405797101449 and parameters: {'C': 1521.6033009218395}. Best is trial 0 with value: 0.3739855072463768.
# [I 2024-02-21 18:52:25,995] Trial 2 finished with value: 0.34543478260869565 and parameters: {'C': 0.11289684905451096}. Best is trial 2 with value: 0.34543478260869565.
# [I 2024-02-21 18:52:43,127] Trial 3 finished with value: 0.408840579710145 and parameters: {'C': 4.402691828613559}. Best is trial 2 with value: 0.34543478260869565.
# [I 2024-02-21 18:53:01,535] Trial 4 finished with value: 0.40326086956521734 and parameters: {'C': 2.936655547001571}. Best is trial 2 with value: 0.34543478260869565.
. Best is trial 13 with value: 0.30797101449275366.
# [I 2024-02-21 18:55:56,447] Trial 29 finished with value: 0.3602898550724638 and parameters: {'C': 0.0005743330347475136}. Best is trial 13 with value: 0.30797101449275366.
# [I 2024-02-21 18:56:02,623] Trial 30 finished with value: 0.3078260869565217 and parameters: {'C': 0.0071768429554127265}. Best is trial 30 with value: 0.3078260869565217.
# [I 2024-02-21 18:56:10,075] Trial 31 finished with value: 0.3081884057971015 and parameters: {'C': 0.008803872739279848}. Best is trial 30 with value: 0.3078260869565217.
# [I 2024-02-21 18:56:23,114] Trial 32 finished with value: 0.3481884057971014 and parameters: {'C': 0.1261490234831862}. Best is trial 30 with value: 0.3078260869565217.
# [I 2024-02-21 18:56:29,444] Trial 33 finished with value: 0.30797101449275366 and parameters: {'C': 0.0072870436189837315}. Best is trial 30 with value: 0.3078260869565217.
# [I 2024-02-21 18:56:40,058] Trial 34 finished with value: 0.34043478260869564 and parameters: {'C': 0.08669467159804961}. Best is trial 30 with value: 0.3078260869565217.
# [I 2024-02-21 18:56:52,993] Trial 35 finished with value: 0.41492753623188405 and parameters: {'C': 12.012248251880427}. Best is trial 30 with value: 0.3078260869565217.
# [I 2024-02-21 18:56:55,495] Trial 36 finished with value: 0.4318840579710145 and parameters: {'C': 0.00011266800003908355}. Best is trial 30 with value: 0.3078260869565217.
# [I 2024-02-21 18:56:59,824] Trial 37 finished with value: 0.3432608695652174 and parameters: {'C': 0.0009692000843001063}. Best is trial 30 with value: 0.3078260869565217.
# [I 2024-02-21 18:57:15,999] Trial 38 finished with value: 0.403840579710145 and parameters: {'C': 2.697106428227563}. Best is trial 30 with value: 0.3078260869565217.
# [I 2024-02-21 18:57:29,384] Trial 39 finished with value: 0.3585507246376811 and parameters: {'C': 0.1936702582227853}. Best is trial 30 with value: 0.3078260869565217.
# [I 2024-02-21 18:57:44,083] Trial 40 finished with value: 0.3729710144927536 and parameters: {'C': 0.35544549352395355}. Best is trial 30 with value: 0.3078260869565217.
# [I 2024-02-21 18:57:50,943] Trial 41 finished with value: 0.31028985507246376 and parameters: {'C': 0.005624381743511241}. Best is trial 30 with value: 0.3078260869565217.
# [I 2024-02-21 18:57:56,893] Trial 42 finished with value: 0.30768115942028984 and parameters: {'C': 0.007204499151941858}. Best is trial 42 with value: 0.30768115942028984.
# [I 2024-02-21 18:58:07,044] Trial 43 finished with value: 0.3278260869565217 and parameters: {'C': 0.04961601489062739}. Best is trial 42 with value: 0.30768115942028984.
# [I 2024-02-21 18:58:12,560] Trial 44 finished with value: 0.31760869565217387 and parameters: {'C': 0.002797698299306726}. Best is trial 42 with value: 0.30768115942028984.
# [I 2024-02-21 18:58:27,383] Trial 45 finished with value: 0.39847826086956517 and parameters: {'C': 1.5105709399179919}. Best is trial 42 with value: 0.30768115942028984.
# [I 2024-02-21 18:58:29,267] Trial 46 finished with value: 0.5043478260869565 and parameters: {'C': 1.5714469123100283e-05}. Best is trial 42 with value: 0.30768115942028984.
# [I 2024-02-21 18:58:33,473] Trial 47 finished with value: 0.3357971014492753 and parameters: {'C': 0.0012767295534289516}. Best is trial 42 with value: 0.30768115942028984.
# [I 2024-02-21 18:58:47,108] Trial 48 finished with value: 0.3863043478260869 and parameters: {'C': 0.635346268495965}. Best is trial 42 with value: 0.30768115942028984.
# [I 2024-02-21 18:58:51,845] Trial 49 finished with value: 0.4288405797101449 and parameters: {'C': 1499.8378711717037}. Best is trial 42 with value: 0.30768115942028984.
# Best Hyperparameters: {'C': 0.007204499151941858}
# Final Model Accuracy: 0.69

# %% [markdown]
# # Save the Model

# %%
import joblib

# %%
def save_model(model, filename):
    try:
        joblib.dump(model, f"./MyModels/{filename}" )
        print(f"Model saved successfully to ./MyModels/{filename}")
    except Exception as e:
        print(f"Error saving the model: {e}")

# %%
save_model(best_model, 'best_logistic_regression_model.joblib')
# Out:
# Model saved successfully to ./MyModels/best_logistic_regression_model.joblib

# %% [markdown]
# # Load the model

# %%
def load_model(filename):
    try:
        model = joblib.load(filename)
        print(f"Model loaded successfully from {filename}")
        return model
    except Exception as e:
        print(f"Error loading the model: {e}")
        return None

# %%
log_reg = load_model('./MyModels/best_logistic_regression_model.joblib')
# Out:
# Model loaded successfully from ./MyModels/best_logistic_regression_model.joblib

# %%
y_pred = log_reg.predict(X_test_pca)
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2%}")
# Out:
# Model Accuracy: 69.23%

# %% [markdown]
# # Test the Logistic regression model

# %%
fig, ax = plt.subplots(6,6, figsize=(15,15))
ax = ax.flatten()

for i in range(36):
    k = np.random.randint(0, len(X_test))
    img = X_test[k]
    img_pca = X_test_pca[k]

    pred_class = log_reg.predict([img_pca])[0]
    true_class = y_test[k]

    if pred_class == true_class:
        color='green'
    else:
        color='red'

    ax[i].imshow(img.reshape(32,32),cmap='gray_r')
    ax[i].axis(False)
    ax[i].set_title(f"Actual Class: {hindi_character[true_class]}\nPredicted Class: {hindi_character[pred_class]}",
                    color=color,
                    fontproperties=hindi_font)

plt.show()

# %%
def single_image_prediction(img,model):
    img_arr = cv2.imread(img,0).flatten().astype("float32")
    img_scaler = scaler.transform(img_arr.reshape(1,-1))
    img_pca = pca.transform(img_scaler)

    y_pred = model.predict(img_pca)[0]
    pred_class = hindi_character[y_pred]

    plt.imshow(img_arr.reshape(32,32),cmap='gray')
    plt.title(f"Predicted Class : {pred_class} ",fontproperties=hindi_font,fontsize=20)
    plt.axis(False)
    plt.show()

# %%
test_img1 = "./DevanagariHandwrittenCharacterDataset_10_per_train_100_per_test/Test/character_1_ka/10963.png"
test_img_2 = "./DevanagariHandwrittenCharacterDataset_10_per_train_100_per_test/Test/character_21_pa/11115.png"

# %%
single_image_prediction(test_img1,log_reg)

# %%
single_image_prediction(test_img_2,log_reg)

# %% [markdown]
# # Model-2: KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Initialize KNN classifier
knn_classifier = KNeighborsClassifier(n_neighbors=5)

# %%
# Fit the classifier on the reduced dimensionality data
knn_classifier.fit(X_train_pca, y_train)
# Out:
# KNeighborsClassifier()

# %%
# Predictions on the test set
y_pred = knn_classifier.predict(X_test_pca)
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "C:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7533333333333333

# %% [markdown]
# # Hyer parameter tuning for KNN

# %%
import optuna
from sklearn.model_selection import cross_val_score

# %%
def objective(trial):
    # Define search space for hyperparameters
    n_neighbors = trial.suggest_int('n_neighbors', 1, 20)
    weights = trial.suggest_categorical('weights', ['uniform', 'distance'])
    
    # Initialize KNN classifier with hyperparameters
    knn_classifier = KNeighborsClassifier(n_neighbors=n_neighbors, weights=weights, n_jobs=-1)

    # Use cross-validation for training and evaluation
    cv_score = cross_val_score(knn_classifier, X_train_pca, y_train, cv=5, scoring='accuracy').mean()

    return cv_score

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)
# Out:
# [I 2024-02-21 18:59:03,518] A new study created in memory with name: no-name-0dde8776-187c-4961-87aa-a8a52dc9b6f9
# [I 2024-02-21 18:59:04,545] Trial 0 finished with value: 0.5140664961636828 and parameters: {'n_neighbors': 20, 'weights': 'uniform'}. Best is trial 0 with value: 0.5140664961636828.
# [I 2024-02-21 18:59:05,455] Trial 1 finished with value: 0.5563938618925831 and parameters: {'n_neighbors': 6, 'weights': 'distance'}. Best is trial 1 with value: 0.5563938618925831.
# [I 2024-02-21 18:59:06,505] Trial 2 finished with value: 0.5281329923273658 and parameters: {'n_neighbors': 20, 'weights': 'distance'}. Best is trial 1 with value: 0.5563938618925831.
# [I 2024-02-21 18:59:07,432] Trial 3 finished with value: 0.5136828644501279 and parameters: {'n_neighbors': 14, 'weights': 'uniform'}. Best is trial 1 with value: 0.5563938618925831.
# [I 2024-02-21 18:59:08,305] Trial 4 finished with value: 0.5570332480818414 and parameters: {'n_neighbors': 2, 'weights': 'distance'}. Best is trial 4 with value: 0.5570332480818414.
# [I 2024-02-21 18:59
predict(X_test_pca)
accuracy = accuracy_score(y_test, y_pred)
print(f"Final Model Accuracy: {accuracy:.2%}")
# Out:
# Final Model Accuracy: 78.05%

# %% [markdown]
# # Save the best Model

# %%
save_model(best_knn_classifier, 'best_knn_classifier_model.joblib')
# Out:
# Model saved successfully to ./MyModels/best_knn_classifier_model.joblib

# %% [markdown]
# # Test the KNN Model

# %%
def pred_and_plot(model):

    fig, ax = plt.subplots(6,6, figsize=(15,15))
    ax = ax.flatten()
    
    for i in range(36):
        k = np.random.randint(0, len(X_test))
        img = X_test[k]
        img_pca = X_test_pca[k]
    
        pred_class = model.predict([img_pca])[0]
        true_class = y_test[k]
    
        if pred_class == true_class:
            color='green'
        else:
            color='red'
    
        ax[i].imshow(img.reshape(32,32),cmap='gray_r')
        ax[i].axis(False)
        ax[i].set_title(f"Actual Class: {hindi_character[true_class]}\nPredicted Class: {hindi_character[pred_class]}",
                        color=color,
                        fontproperties=hindi_font)
    
    plt.show()

# %%
pred_and_plot(best_knn_classifier)

# %%
test_img1 = "./DevanagariHandwrittenCharacterDataset_10_per_train_100_per_test/Test/character_28_la/11430.png"
test_img_2 = "./DevanagariHandwrittenCharacterDataset_10_per_train_100_per_test/Test/character_21_pa/11115.png"

# %%
single_image_prediction(test_img1,best_knn_classifier)

# %%
single_image_prediction(test_img_2,best_knn_classifier)

# %% [markdown]
# # Model-3 : Support Vector Classifier

# %%
from sklearn.svm import SVC

# %%
# Initialize SVC with default parameters
svc_classifier = SVC()

# %%
# Fit the classifier on the reduced dimensionality data
svc_classifier.fit(X_train_pca, y_train)
# Out:
# SVC()

# %%
# Predictions on the test set
y_pred = svc_classifier.predict(X_test_pca)

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.8338405797101449

# %% [markdown]
# # Hyper parameter tunning for SVC

# %%
import optuna
from sklearn.model_selection import cross_val_score

# %%
def objective(trial):
    # Define search space for hyperparameters
    C = trial.suggest_float('C', 1e-5, 1e5,log=True)
    kernel = trial.suggest_categorical('kernel', ['linear', 'rbf', 'poly'])   # , 'sigmoid'
    degree = trial.suggest_int('degree', 2, 5) # if kernel == 'poly' else None
    gamma = trial.suggest_categorical('gamma', ['scale', 'auto']) # if kernel in ['rbf', 'poly', 'sigmoid'] else 'scale'

    # C = trial.suggest_float('C', 1e-3, 1e3, log=True)
    # kernel = trial.suggest_categorical('kernel', ['linear', 'rbf', 'poly'])
    # gamma = trial.suggest_float('gamma', 1e-3, 1e3, log=True)

    # Initialize SVC classifier with hyperparameters
    svc_classifier = SVC(C=C, kernel=kernel, degree=degree, gamma=gamma)

    # Use cross-validation for training and evaluation
    cv_score = cross_val_score(svc_classifier, X_train_pca, y_train, cv=5, scoring='accuracy').mean()

    return cv_score

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50, n_jobs=-1)
# Out:
# [I 2024-02-21 19:01:30,516] A new study created in memory with name: no-name-1fb8f4ce-fb86-4970-a20d-aab4db3b80c9
# [I 2024-02-21 19:02:35,714] Trial 2 finished with value: 0.6063938618925832 and parameters: {'C': 9.529185385350758, 'kernel': 'linear', 'degree': 2, 'gamma': 'scale'}. Best is trial 2 with value: 0.6063938618925832.
# [I 2024-02-21 19:02:45,414] Trial 7 finished with value: 0.5850383631713555 and parameters: {'C': 0.0005706571748865239, 'kernel': 'linear', 'degree': 2, 'gamma': 'scale'}. Best is trial 2 with value: 0.6063938618925832.
# [I 2024-02-21 19:02:48,554] Trial 5 finished with value: 0.5755754475703325 and parameters: {'C': 0.0004413764123586775, 'kernel': 'linear', 'degree': 2, 'gamma': 'auto'}. Best is trial 2 with value: 0.6063938618925832.
# [I 2024-02-21 19:04:09,076] Trial 0 finished with value: 0.5434782608695652 and parameters: {'C': 12844.261739830961, 'kernel': 'poly', 'degree': 4, 'gamma': 'scale'}. Best is trial 2 with value: 0.6063938618925832.
# [I 2024-02-21 19:04:09,160] Trial 3 finished with value: 0.5434782608695652 and parameters: {'C': 152.78479114873434, 'kernel': 'poly', 'degree': 4, 'gamma': 'scale'}. Best is trial
 'kernel': 'rbf', 'degree': 5, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:14:17,181] Trial 34 finished with value: 0.6892583120204603 and parameters: {'C': 1555.2318755911954, 'kernel': 'rbf', 'degree': 5, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:14:19,295] Trial 35 finished with value: 0.6892583120204603 and parameters: {'C': 1067.1387239256073, 'kernel': 'rbf', 'degree': 5, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:14:24,600] Trial 36 finished with value: 0.6892583120204603 and parameters: {'C': 2712.933241994962, 'kernel': 'rbf', 'degree': 4, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:14:26,413] Trial 37 finished with value: 0.6892583120204603 and parameters: {'C': 68.24359065057628, 'kernel': 'rbf', 'degree': 4, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:15:12,001] Trial 38 finished with value: 0.6892583120204603 and parameters: {'C': 2493.6063954047663, 'kernel': 'rbf', 'degree': 5, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:15:32,820] Trial 39 finished with value: 0.6892583120204603 and parameters: {'C': 2384.5461633642835, 'kernel': 'rbf', 'degree': 5, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:15:33,705] Trial 40 finished with value: 0.6892583120204603 and parameters: {'C': 37.4678586259799, 'kernel': 'rbf', 'degree': 4, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:16:53,636] Trial 43 finished with value: 0.5434782608695652 and parameters: {'C': 72.30105702160536, 'kernel': 'poly', 'degree': 4, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:16:55,224] Trial 41 finished with value: 0.5434782608695652 and parameters: {'C': 26.25234281470987, 'kernel': 'poly', 'degree': 4, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:16:56,198] Trial 42 finished with value: 0.5434782608695652 and parameters: {'C': 60.484901962308804, 'kernel': 'poly', 'degree': 4, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:17:01,604] Trial 44 finished with value: 0.5434782608695652 and parameters: {'C': 48.00760766667022, 'kernel': 'poly', 'degree': 4, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:17:02,407] Trial 45 finished with value: 0.5360613810741688 and parameters: {'C': 4.759187513925292, 'kernel': 'poly', 'degree': 4, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:17:34,779] Trial 46 finished with value: 0.5434782608695652 and parameters: {'C': 15.69196638653561, 'kernel': 'poly', 'degree': 4, 'gamma': 'auto'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:17:49,889] Trial 47 finished with value: 0.5434782608695652 and parameters: {'C': 4.727852254059264, 'kernel': 'poly', 'degree': 4, 'gamma': 'auto'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:17:50,153] Trial 48 finished with value: 0.5396419437340153 and parameters: {'C': 5.923098309031661, 'kernel': 'poly', 'degree': 4, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.
# [I 2024-02-21 19:18:37,352] Trial 49 finished with value: 0.5354219948849105 and parameters: {'C': 4.661032335637901, 'kernel': 'poly', 'degree': 4, 'gamma': 'scale'}. Best is trial 4 with value: 0.6892583120204603.

# %%
# Get the best hyperparameters
best_params = study.best_params
print("Best Hyperparameters:", best_params)
# Out:
# Best Hyperparameters: {'C': 2380.109815908594, 'kernel': 'rbf', 'degree': 4, 'gamma': 'scale'}

# %%
best_svc_classifier = SVC(C=best_params['C'],kernel=best_params['kernel'],degree=best_params['degree'],gamma=best_params['gamma'])
best_svc_classifier.fit(X_train_pca,y_train)
# Out:
# SVC(C=2380.109815908594, degree=4)

# %%
# Evaluate the performance on the test set
y_pred = best_svc_classifier.predict(X_test_pca)
accuracy = accuracy_score(y_test, y_pred)
print(f"Final Model Accuracy: {accuracy:.2%}")
# Out:
# Final Model Accuracy: 86.47%

# %% [markdown]
# # Save the best SVC model

# %%
import joblib

# %%
save_model(best_svc_classifier, 'best_svc_classifier_model.joblib')
# Out:
# Model saved successfully to ./MyModels/best_svc_classifier_model.joblib

# %% [markdown]
# # Test the SVC model

# %%
pred_and_plot(best_svc_classifier)

# %%
test_img_1 = "./DevanagariHandwrittenCharacterDataset_10_per_train_100_per_test/Test/character_28_la/11430.png"
test_img_2 = "./DevanagariHandwrittenCharacterDataset_10_per_train_100_per_test/Test/character_21_pa/11115.png"

# %%
single_image_prediction(test_img_1,best_svc_classifier)

# %%
single_image_prediction(test_img_2,best_svc_classifier)

# %% [markdown]
# # Model-4 : Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Initialize RandomForestClassifier with default parameters
rf_classifier = RandomForestClassifier()

# %%
# Fit the classifier on the reduced dimensionality data
rf_classifier.fit(X_train_pca, y_train)
# Out:
# RandomForestClassifier()

# %%
# Predictions on the test set
y_pred = rf_classifier.predict(X_test_pca)

# %%
# Calculate accuracy
accuracy= accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.6284057971014493

# %% [markdown]
# # Hyper parameter tunning for Random Forest

# %%
import optuna
from sklearn.model_selection import cross_val_score

# %%
def objective(trial):
    # Define search space for hyperparameters
    n_estimators = trial.suggest_int('n_estimators', 100, 500)
    max_depth = trial.suggest_int('max_depth', 2, 32, log=True)
    min_samples_split = trial.suggest_int('min_samples_split', 2, 20)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 10)

    # Initialize RandomForestClassifier with hyperparameters
    rf_classifier = RandomForestClassifier(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        random_state=42  # Ensure reproducibility
    )

    # Use cross-validation for training and evaluation
    cv_score = cross_val_score(rf_classifier, X_train_pca, y_train, cv=5, scoring='accuracy').mean()

    return cv_score

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50, n_jobs=-1)
# Out:
# [I 2024-02-21 19:21:56,092] A new study created in memory with name: no-name-fcad36d4-b4e8-48d1-a52c-fe4abbf7057d
# [I 2024-02-21 19:31:40,373] Trial 7 finished with value: 0.3387468030690537 and parameters: {'n_estimators': 264, 'max_depth': 2, 'min_samples_split': 11, 'min_samples_leaf': 10}. Best is trial 7 with value: 0.3387468030690537.
# [I 2024-02-21 19:34:09,480] Trial 4 finished with value: 0.47442455242966747 and parameters: {'n_estimators': 111, 'max_depth': 11, 'min_samples_split': 14, 'min_samples_leaf': 7}. Best is trial 4 with value: 0.47442455242966747.
# [I 2024-02-21 19:35:42,442] Trial 0 finished with value: 0.49309462915601027 and parameters: {'n_estimators': 128, 'max_depth': 14, 'min_samples_split': 6, 'min_samples_leaf': 7}. Best is trial 0 with value: 0.49309462915601027.
# [I 2024-02-21 20:42:03,805] Trial 10 finished with value: 0.33951406649616367 and parameters: {'n_estimators': 382, 'max_depth': 2, 'min_samples_split': 13, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.49309462915601027.
# [I 2024-02-21 20:42:08,847] Trial 2 finished with value: 0.43964194373401544 and parameters: {'n_estimators': 419, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 4}. Best is trial 0 with value: 0.49309462915601027.
# [I 2024-02-21 20:42:39,159] Trial 3 finished with value: 0.5025575447570333 and parameters: {'n_estimators': 205, 'max_depth': 12, 'min_samples_split': 4, 'min_samples_leaf': 1}. Best is trial 3 with value: 0.5025575447570333.
# [I 2024-02-21 20:43:22,929] Trial 6 finished with value: 0.49398976982097187 and parameters: {'n_estimators': 288, 'max_depth': 9, 'min_samples_split': 4, 'min_samples_leaf': 9}. Best is trial 3 with value: 0.5025575447570333.
# [I 2024-02-21 21:00:07,828] Trial 1 finished with value: 0.5149616368286445 and parameters: {'n_estimators': 229, 'max_depth': 23, 'min_samples_split': 20, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.5149616368286445.
# [I 2024-02-21 21:00:48,174] Trial 8 finished with value: 0.5118925831202046 and parameters: {'n_estimators': 218, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 7}. Best is trial 1 with value: 0.5149616368286445.
# [I 2024-02-21 21:02:05,514] Trial 14 finished with value: 0.3656010230179028 and parameters: {'n_estimators': 189, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 10}. Best is trial 1 with value: 0.5149616368286445.
# [I 2024-02-21 21:02:33,406] Trial 12 finished with value: 0.34232736572890027 and parameters: {'n_estimators': 408, 'max_depth': 2, 'min_samples_split': 6, 'min_samples_leaf': 4}. Best is trial 1 with value: 0.5149616368286445.
# [I 2024-02-21 21:29:41,760] Trial 15 finished with value: 0.3694373401534527 and parameters: {'n_estimators': 247, 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 5}. Best is trial 1 with value: 0.5149616368286445.
# [I 2024-02-21 21:31:46,028] Trial 16 finished with value: 0.4367007672634271 and parameters: {'n_estimators': 174, 'max_depth': 6, 'min_samples_split': 11, 'min_samples_leaf': 6}. Best is trial 1 with value: 0.5149616368286445.
# [I 2024-02-21 21:40:08,682] Trial 9 finished with value: 0.5291560102301791 and parameters: {'n_estimators': 395, 'max_depth': 13, 'min_samples_split': 12, 'min_samples_leaf': 4}. Best is trial 9 with value: 0.5291560102301791.
# [I 2024-02-21 21:41:02,789] Trial 11 finished with value: 0.5164961636828644 and parameters: {'n_estimators': 350, 'max_depth': 12, 'min_samples_split': 9, 'min_samples_leaf': 10}. Best is trial 9 with value: 0.5291560102301791.
# [I 2024-02-21 21:42:01,403] Trial 18 finished with value: 0.5161125319693095 and parameters: {'n_estimators': 220, 'max_depth': 31, 'min_samples_split': 18, 'min_samples_leaf': 6}. Best is trial 9 with value: 0.5291560102301791.

# %%
# Get the best hyperparameters
best_params = study.best_params
print("Best Hyperparameters:", best_params)

# %%
# Initialize RandomForestClassifier with best hyperparameters
best_rf_classifier = RandomForestClassifier(
    n_estimators=best_params['n_estimators'],
    criterion=best_params['criterion'],
    max_depth=best_params['max_depth'],
    min_samples_split=best_params['min_samples_split'],
    min_samples_leaf=best_params['min_samples_leaf'],
    max_features=best_params['max_features']
)

# %%
# Fit the best classifier on the training data
best_rf_classifier.fit(X_train_pca, y_train)

# %%
# Evaluate the performance on the test set
y_pred_rf = best_rf_classifier.predict(X_test_pca)
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f"Final Random Forest Accuracy: {accuracy_rf:.2%}")
